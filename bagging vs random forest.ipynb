# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier,plot_tree
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.datasets import make_classification

# %%
x,y = make_classification(n_features=5,n_redundant=0,n_informative=5,n_clusters_per_class=1)

# %%
df = pd.DataFrame(x,columns=["col1","col2","col3","col4,","col5"])
df["target"] = y
df
# Out:
#         col1      col2      col3     col4,      col5  target
# 0  -1.217984 -2.009187 -1.111500  0.797798  1.432087       0
# 1  -3.560366 -0.912899  1.902050  0.287679  2.157651       1
# 2  -0.783590 -0.989600 -2.605311  3.027759 -0.453868       1
# 3  -1.233329 -1.439134 -0.031153 -1.292604  0.396457       0
# 4  -4.013897 -1.054130  0.731330  2.540117  0.162496       1
# ..       ...       ...       ...       ...       ...     ...
# 95 -1.680390 -1.058631 -3.451171 -1.209898  1.530312       0
# 96 -2.227755 -0.462731  0.874479 -1.299851  3.011635       1
# 97  0.139042  1.603624 -1.546845 -1.478641  1.599594       0
# 98 -0.818319 -0.433522 -1.919789  1.000454  1.537797       1
# 99 -1.499422 -1.156522 -0.563564 -0.015104  1.794804       0
#
# [100 rows x 6 columns]

# %%
bag = BaggingClassifier(max_features=2)

# %%
bag.fit(df.iloc[:,0:5],df.iloc[:,-1])
# Out:
# BaggingClassifier(max_features=2)

# %%
plt.figure(figsize=(12,12))
plot_tree(bag.estimators_[0])
plt.show()

# %%
rf=RandomForestClassifier(max_features=3)

# %%
rf.fit(df.iloc[:,:5],df.iloc[:,-1])

plt.figure(figsize=(12,12))
plot_tree(rf.estimators_[0])
plt.show()

# %%
rf.estimators_
# Out:
# [DecisionTreeClassifier(max_features=2, random_state=2139494804),
#  DecisionTreeClassifier(max_features=2, random_state=1621647245),
#  DecisionTreeClassifier(max_features=2, random_state=597594729),
#  DecisionTreeClassifier(max_features=2, random_state=635171990),
#  DecisionTreeClassifier(max_features=2, random_state=157572057),
#  DecisionTreeClassifier(max_features=2, random_state=436388557),
#  DecisionTreeClassifier(max_features=2, random_state=93343109),
#  DecisionTreeClassifier(max_features=2, random_state=786387720),
#  DecisionTreeClassifier(max_features=2, random_state=285116367),
#  DecisionTreeClassifier(max_features=2, random_state=869317229),
#  DecisionTreeClassifier(max_features=2, random_state=838664195),
#  DecisionTreeClassifier(max_features=2, random_state=505176665),
#  DecisionTreeClassifier(max_features=2, random_state=448047409),
#  DecisionTreeClassifier(max_features=2, random_state=2141027760),
#  DecisionTreeClassifier(max_features=2, random_state=1775280740),
#  DecisionTreeClassifier(max_features=2, random_state=917530915),
#  DecisionTreeClassifier(max_features=2, random_state=1552321075),
#  DecisionTreeClassifier(max_features=2, random_state=672440085),
#  DecisionTreeClassifier(max_features=2, random_state=1770512957),
#  DecisionTreeClassifier(max_features=2, random_state=1559950871),
#  DecisionTreeClassifier(max_features=2, random_state=1050166318),
#  DecisionTreeClassifier(max_features=2, random_state=609448573),
#  DecisionTreeClassifier(max_features=2, random_state=1751368927),
#  DecisionTreeClassifier(max_features=2, random_state=677688922),
#  DecisionTreeClassifier(max_features=2, random_state=429418510),
#  DecisionTreeClassifier(max_features=2, random_state=138111345),
#  DecisionTreeClassifier(max_features=2, random_state=1934450933),
#  DecisionTreeClassifier(max_features=2, random_state=1192076586),
#  DecisionTreeClassifier(max_features=2, random_state=1118539360),
#  DecisionTreeClassifier(max_features=2, random_state=1827054755),
#  DecisionTreeClassifier(max_features=2, random_state=985497154),
#  DecisionTreeClassifier(max_features=2, random_state=1413386846),
#  DecisionTreeClassifier(max_features=2, random_state=1233747235),
#  DecisionTreeClassifier(max_features=2, random_state=1406443351),
#  DecisionTreeClassifier(max_features=2, random_state=692650627),
#  DecisionTreeClassifier(max_features=2, random_state=1923542423),
#  DecisionTreeClassifier(max_features=2, random_state=210436535),
#  DecisionTreeClassifier(max_features=2, random_state=434878396),
#  DecisionTreeClassifier(max_features=2, random_state=426750695),
#  DecisionTreeClassifier(max_features=2, random_state=333272356),
#  DecisionTreeClassifier(max_features=2, random_state=1168761723),
#  DecisionTreeClassifier(max_features=2, random_state=1767086742),
#  DecisionTreeClassifier(max_features=2, random_state=558769803),
#  DecisionTreeClassifier(max_features=2, random_state=1034380941),
#  DecisionTreeClassifier(max_features=2, random_state=2143667486),
#  DecisionTreeClassifier(max_features=2, random_state=235506298),
#  DecisionTreeClassifier(max_features=2, random_state=932929291),
#  DecisionTreeClassifier(max_features=2, random_state=1943527771),
#  DecisionTreeClassifier(max_features=2, random_state=148984225),
#  DecisionTreeClassifier(max_features=2, random_state=622082531),
#  DecisionTreeClassifier(max_features=2, random_state=792436162),
#  DecisionTreeClassifier(max_features=2, random_state=604216635),
#  DecisionTreeClassifier(max_features=2, random_state=175126549),
#  DecisionTreeClassifier(max_features=2, random_state=358825080),
#  DecisionTreeClassifier(max_features=2, random_state=1350097160),
#  DecisionTreeClassifier(max_features=2, random_state=609630805),
#  DecisionTreeClassifier(max_features=2, random_state=741490857),
#  DecisionTreeClassifier(max_features=2, random_state=1852651723),
#  DecisionTreeClassifier(max_features=2, random_state=1598096494),
#  DecisionTreeClassifier(max_features=2, random_state=845084858),
#  DecisionTreeClassifier(max_features=2, random_state=1353554016),
#  DecisionTreeClassifier(max_features=2, random_state=346152920),
#  DecisionTreeClassifier(max_features=2, random_state=1856907545),
#  DecisionTreeClassifier(max_features=2, random_state=1929450940),
#  DecisionTreeClassifier(max_features=2, random_state=791160763),
#  DecisionTreeClassifier(max_features=2, random_state=1594638844),
#  DecisionTreeClassifier(max_features=2, random_state=1068753964),
#  DecisionTreeClassifier(max_features=2, random_state=483024472),
#  DecisionTreeClassifier(max_features=2, random_state=1866451733),
#  DecisionTreeClassifier(max_features=2, random_state=510441065),
#  DecisionTreeClassifier(max_features=2, random_state=610711134),
#  DecisionTreeClassifier(max_features=2, random_state=1257870323),
#  DecisionTreeClassifier(max_features=2, random_state=1363007706),
#  DecisionTreeClassifier(max_features=2, random_state=1630510878),
#  DecisionTreeClassifier(max_features=2, random_state=939313491),
#  DecisionTreeClassifier(max_features=2, random_state=804822285),
#  DecisionTreeClassifier(max_features=2, random_state=1866493998),
#  DecisionTreeClassifier(max_features=2, random_state=2082721378),
#  DecisionTreeClassifier(max_features=2, random_state=181151218),
#  DecisionTreeClassifier(max_features=2, random_state=258355158),
#  DecisionTreeClassifier(max_features=2, random_state=586820908),
#  DecisionTreeClassifier(max_features=2, random_state=1837160699),
#  DecisionTreeClassifier(max_features=2, random_state=666515833),
#  DecisionTreeClassifier(max_features=2, random_state=1048814512),
#  DecisionTreeClassifier(max_features=2, random_state=1162174128),
#  DecisionTreeClassifier(max_features=2, random_state=1103027031),
#  DecisionTreeClassifier(max_features=2, random_state=240872859),
#  DecisionTreeClassifier(max_features=2, random_state=1101682966),
#  DecisionTreeClassifier(max_features=2, random_state=2027468369),
#  DecisionTreeClassifier(max_features=2, random_state=1098680427),
#  DecisionTreeClassifier(max_features=2, random_state=1334244262),
#  DecisionTreeClassifier(max_features=2, random_state=1992556148),
#  DecisionTreeClassifier(max_features=2, random_state=282892281),
#  DecisionTreeClassifier(max_features=2, random_state=1323800938),
#  DecisionTreeClassifier(max_features=2, random_state=1957089727),
#  DecisionTreeClassifier(max_features=2, random_state=1631205082),
#  DecisionTreeClassifier(max_features=2, random_state=835901031),
#  DecisionTreeClassifier(max_features=2, random_state=1276826889),
#  DecisionTreeClassifier(max_features=2, random_state=71517742),
#  DecisionTreeClassifier(max_features=2, random_state=259706980)]
